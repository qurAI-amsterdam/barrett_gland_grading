# %%
from wholeslidedata.iterators import create_batch_iterator
from matplotlib import pyplot as plt
from plot_utils import init_plot, plot_batch, show_plot
from shapely.prepared import prep
import os
import numpy as np
import torch
from nn_archs import UNet
from pprint import pprint
from torchsummary import summary

# %%
# a standard vanilla UNet (with valid convs)
model = UNet(n_channels=3, n_classes=4)
summary(model, input_size=(3, 512, 512), batch_size=1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [1, 64, 510, 510]           1,792
#        BatchNorm2d-2          [1, 64, 510, 510]             128
#               ReLU-3          [1, 64, 510, 510]               0
#             Conv2d-4          [1, 64, 508, 508]          36,928
#        BatchNorm2d-5          [1, 64, 508, 508]             128
#               ReLU-6          [1, 64, 508, 508]               0
#         DoubleConv-7          [1, 64, 508, 508]               0
#          MaxPool2d-8          [1, 64, 254, 254]               0
#             Conv2d-9         [1, 128, 252, 252]          73,856
#       BatchNorm2d-10         [1, 128, 252, 252]             256
#              ReLU-11         [1, 128, 252, 252]               0
#            Conv2d-12         [1, 128, 250, 250]         147,584
#       BatchNorm2d-13         [1, 128, 250, 250]             256
# ...

# %%
# (1) create a batch iterator
user_config = './configs/user_config.yml'
batches = 2 # how many batches that are going to be sampled, batchgenerator will be reset afterwards
repeats = 1
cpus = 1
mode = 'training'

with create_batch_iterator(user_config=user_config, 
                            number_of_batches=batches, 
                            mode=mode, 
                            cpus=cpus) as training_batch_generator:
    
    # print dataset stats
    print('Dataset:')
    pprint(training_batch_generator.dataset.annotations_per_label_per_key)
    
    for r in range(repeats):
        fig, axes = init_plot(batches, training_batch_generator.batch_size)
        for idx, (x_batch, y_batch, info) in enumerate(training_batch_generator):
            plot_batch(axes, idx, x_batch, y_batch)
            print('x shape: {}'.format(x_batch.shape))
            print('y shape: {}'.format(y_batch.shape))
            print('y contains: {}'.format(np.unique(y_batch, return_counts=True)))
    show_plot(fig, r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9692/654681108.py in <module>
#       6 mode = 'training'
#       7
# ----> 8 with create_batch_iterator(user_config=user_config,
#       9                             number_of_batches=batches,
#      10                             mode=mode,
#
# ~\Anaconda3\lib\site-packages\wholeslidedata\iterators.py in create_batch_iterator(user_config, mode, number_of_batches, index, update_samplers, return_info, search_paths, presets, cpus, context, determinstic, buffer_dtype, iterator_class)
#     133     )
#     134
# --> 135     builds = WholeSlideDataConfiguration.build(
#     136         user_config=user_config,
#     137         modes=(mode,),
#
# ...

# %%
# lets print some configs
print(us)
